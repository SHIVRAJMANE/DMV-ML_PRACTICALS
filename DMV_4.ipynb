# %% [markdown]
# Imports

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from scipy import stats

# %%
data = pd.read_csv("Mumbai_Property.csv")

# %% [markdown]
# Data Preprocessing

# %%
data.head()
# Out:
#                   Property_Name
# 0             Omkar Alta Monte   \
# 1  T Bhimjyani Neelkanth Woods
# 2       Legend 1 Pramila Nagar
# 3              Unnamed Property
# 4              Unnamed Property
#
#                                             Location            Region
# 0                      W E Highway Malad East Mumbai      Malad Mumbai  \
# 1                               Manpada Thane Mumbai     Manpada Thane
# 2                                Dahisar West Mumbai    Dahisar Mumbai
# 3  Vidyavihar West Vidyavihar West Central Mumbai...    Central Mumbai
# 4  176 Cst Road Kalina Mumbai 400098 Santacruz Ea...  Santacruz Mumbai
#
#    Property_Age   Availability            Area_Tpye  Area_SqFt  Rate_SqFt
# 0   0 to 1 Year  Ready To Move  Super Built Up Area     2900.0      17241  \
# 1   1 to 5 Year  Ready To Move  Super Built Up Area     1900.0      12631
# 2      10+ Year  Ready To Move  Super Built Up Area      595.0      15966
# 3  5 to 10 Year  Ready To Move        Built Up Area     1450.0      25862
# 4  5 to 10 Year  Ready To Move          Carpet Area      876.0      39954
#
#    Floor_No  Bedroom  Bathroom  Price_Lakh
# 0        14        3         4       500.0
# 1         8        3         3       240.0
# 2         3        1         2        95.0
# 3         1        3         3       375.0
# 4         5        2         2       350.0

# %%
data.tail()
# Out:
#                  Property_Name                           Location
# 2575       Shagun White Woods   Sector 23 Ulwe Navi Mumbai Mumbai  \
# 2576               Guru Anant    Sector 2 Ulwe Navi Mumbai Mumbai
# 2577    Balaji Mayuresh Delta             Ulwe Navi Mumbai Mumbai
# 2578    Balaji Mayuresh Delta             Ulwe Navi Mumbai Mumbai
# 2579  Gurukrupa Tulsi Heights             Ulwe Navi Mumbai Mumbai
#
#                 Region Property_Age   Availability      Area_Tpye  Area_SqFt
# 2575  Ulwe Navi-Mumbai  1 to 5 Year  Ready To Move  Built Up Area     1180.0  \
# 2576  Ulwe Navi-Mumbai  0 to 1 Year  Ready To Move  Built Up Area     1090.0
# 2577  Ulwe Navi-Mumbai  1 to 5 Year  Ready To Move  Built Up Area     1295.0
# 2578  Ulwe Navi-Mumbai  1 to 5 Year  Ready To Move  Built Up Area     1850.0
# 2579  Ulwe Navi-Mumbai  0 to 1 Year  Ready To Move  Built Up Area     1100.0
#
#       Rate_SqFt  Floor_No  Bedroom  Bathroom  Price_Lakh
# 2575      10338         2        2         2       122.0
# 2576       8073        11        2         2        88.0
# 2577      10579         6        2         2       137.0
# 2578       9243         6        3         3       171.0
# 2579       8636         4        2         2        95.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Property_Name  2580 non-null   object
#  1   Location       2580 non-null   object
#  2   Region         2580 non-null   object
#  3   Property_Age   2580 non-null   object
#  4   Availability   2580 non-null   object
#  5   Area_Tpye      2580 non-null   object
#  6   Area_SqFt      2580 non-null   float64
#  7   Rate_SqFt      2580 non-null   int64
#  8   Floor_No       2580 non-null   int64
#  9   Bedroom        2580 non-null   int64
#  10  Bathroom       2580 non-null   int64
#  11  Price_Lakh     2580 non-null   float64
# dtypes: float64(2), int64(4), object(6)
# memory usage: 242.0+ KB

# %%
data.columns
# Out:
# Index(['Property_Name', 'Location', 'Region', 'Property_Age', 'Availability',
#        'Area_Tpye', 'Area_SqFt', 'Rate_SqFt', 'Floor_No', 'Bedroom',
#        'Bathroom', 'Price_Lakh'],
#       dtype='object')

# %%
data.describe()
# Out:
#            Area_SqFt     Rate_SqFt     Floor_No      Bedroom     Bathroom
# count    2580.000000  2.580000e+03  2580.000000  2580.000000  2580.000000  \
# mean     1026.105058  1.911185e+04     8.839535     1.962016     2.066667
# std      2287.126278  4.076088e+04     8.100081     0.844726     0.749960
# min        33.570000  8.400000e+01    -1.000000     1.000000     1.000000
# 25%       630.750000  8.791750e+03     3.000000     1.000000     2.000000
# 50%       850.000000  1.378500e+04     6.000000     2.000000     2.000000
# 75%      1156.000000  2.265000e+04    12.000000     2.000000     2.000000
# max    100000.000000  1.650000e+06    59.000000     6.000000     7.000000
#
#          Price_Lakh
# count   2580.000000
# mean     174.389806
# std      369.484393
# min       13.000000
# 25%       67.000000
# 50%      111.500000
# 75%      200.000000
# max    16500.000000

# %% [markdown]
# Clean column names by removing spaces, special characters, or renaming them for clarity.

# %%
data.columns = data.columns.str.replace(' ', '_') 
data.columns = data.columns.str.replace('[^a-zA-Z0-9_]', '')

# %%
data = data.rename(columns={'Area_Tpye': 'Area_Type'})

# %%
print(data.Area_Type.unique())
print(data.Availability.unique())
print(data.Property_Age.unique())
# Out:
# ['Super Built Up Area' 'Built Up Area' 'Carpet Area' 'Plot Area']
# ['Ready To Move' 'Under Construction']
# ['0 to 1 Year' '1 to 5 Year' '10+ Year' '5 to 10 Year'
#  'Under Construction']

# %% [markdown]
#  Handle missing values in the dataset, deciding on an appropriate strategy

# %%
data.isna().sum()
# Out:
# Property_Name    0
# Location         0
# Region           0
# Property_Age     0
# Availability     0
# Area_Type        0
# Area_SqFt        0
# Rate_SqFt        0
# Floor_No         0
# Bedroom          0
# Bathroom         0
# Price_Lakh       0
# dtype: int64

# %% [markdown]
# No missing values

# %% [markdown]
#  Filter and subset the data based on specific criteria, such as a particular time period, property type, or location

# %%
filtered_data_1 = data[(data['Price_Lakh'] >= 2000) & (data['Availability'] == 'Ready To Move')]

# %%
filtered_data_1
# Out:
#          Property_Name                       Location            Region
# 1416  Unnamed Property  Juhu Mumbai South West Mumbai       Juhu Mumbai  \
# 2065       White City       005 Kandivali East Mumbai  Kandivali Mumbai
#
#      Property_Age   Availability            Area_Type  Area_SqFt  Rate_SqFt
# 1416     10+ Year  Ready To Move  Super Built Up Area     5700.0      42105  \
# 2065  0 to 1 Year  Ready To Move  Super Built Up Area     1000.0    1650000
#
#       Floor_No  Bedroom  Bathroom  Price_Lakh
# 1416         1        4         4      2400.0
# 2065        21        2         2     16500.0

# %%
filtered_data_2 = data[(data['Area_Type'] == 'Plot Area') & (data['Bedroom'] >2)]
filtered_data_2
# Out:
#             Property_Name                                           Location
# 97       Unnamed Property  Ramdev Park Ramdev Park Mira Road And Beyond M...  \
# 104      Unnamed Property                      New Panvel Navi Mumbai Mumbai
# 183      Unnamed Property                    Wada Mumbai Beyond Thane Mumbai
# 237      Unnamed Property           O 13 Sector 9 Belapur Navi Mumbai Mumbai
# 281      Unnamed Property                 Sector 2 Airoli Navi Mumbai Mumbai
# 345      Unnamed Property                Sector 9 Belapur Navi Mumbai Mumbai
# 521      Unnamed Property  Sector 1 Koparkhairane Sector 1 Koparkhairane ...
# 567      Unnamed Property                           101 Manpada Thane Mumbai
# 1201  Ravi Gaurav Greens          Mira Road East Mira Road And Beyond Mumbai
# 1984     Unnamed Property                  Khardi Mumbai Beyond Thane Mumbai
#
#                          Region  Property_Age   Availability  Area_Type
# 97                    Mira Road      10+ Year  Ready To Move  Plot Area  \
# 104          Panvel Navi-Mumbai   0 to 1 Year  Ready To Move  Plot Area
# 183                 Wada Mumbai  5 to 10 Year  Ready To Move  Plot Area
# 237         Belapur Navi-Mumbai      10+ Year  Ready To Move  Plot Area
# 281          Airoli Navi-Mumbai      10+ Year  Ready To Move  Plot Area
# 345         Belapur Navi-Mumbai      10+ Year  Ready To Move  Plot Area
# 521   Koparkhairane Navi-Mumbai  5 to 10 Year  Ready To Move  Plot Area
# 567               Manpada Thane  5 to 10 Year  Ready To Move  Plot Area
# 1201                  Mira Road  5 to 10 Year  Ready To Move  Plot Area
# 1984               Mumbai Thane      10+ Year  Ready To Move  Plot Area
#
#       Area_SqFt  Rate_SqFt  Floor_No  Bedroom  Bathroom  Price_Lakh
# 97       3000.0      18666         4        6         7       560.0
# 104       210.0     247619         4        5         4       520.0
# 183      2400.0       2291         1        3         2        55.0
# 237      2000.0       8750         2        3         2       175.0
# 281      1200.0      13750         3        3         2       165.0
# 345       922.0      27223         2        4         3       251.0
# 521       200.0      34500         3        3         3        69.0
# 567      2700.0      27777         2        4         4       750.0
# 1201   100000.0        290         2        4         4       290.0
# 1984     8500.0       1752         2        3         3       149.0

# %% [markdown]
# Handle categorical variables by encoding them appropriately (e.g., one-hot encoding or label encoding) for further analysis.

# %%
data = pd.get_dummies(data, columns=['Property_Age'], prefix=['Property_Age'])

# %%
label_encoder = LabelEncoder()

# %%
column_to_encode=['Area_Type','Availability']
label_encoder=LabelEncoder()
for col in column_to_encode:
    data[col] = label_encoder.fit_transform(data[col])

# %%
data.head()
# Out:
#                   Property_Name
# 0             Omkar Alta Monte   \
# 1  T Bhimjyani Neelkanth Woods
# 2       Legend 1 Pramila Nagar
# 3              Unnamed Property
# 4              Unnamed Property
#
#                                             Location            Region
# 0                      W E Highway Malad East Mumbai      Malad Mumbai  \
# 1                               Manpada Thane Mumbai     Manpada Thane
# 2                                Dahisar West Mumbai    Dahisar Mumbai
# 3  Vidyavihar West Vidyavihar West Central Mumbai...    Central Mumbai
# 4  176 Cst Road Kalina Mumbai 400098 Santacruz Ea...  Santacruz Mumbai
#
#    Availability  Area_Type  Area_SqFt  Rate_SqFt  Floor_No  Bedroom  Bathroom
# 0             0          3     2900.0      17241        14        3         4  \
# 1             0          3     1900.0      12631         8        3         3
# 2             0          3      595.0      15966         3        1         2
# 3             0          0     1450.0      25862         1        3         3
# 4             0          1      876.0      39954         5        2         2
#
#    Price_Lakh  Property_Age_0 to 1 Year  Property_Age_1 to 5 Year
# 0       500.0                      True                     False  \
# 1       240.0                     False                      True
# 2        95.0                     False                     False
# 3       375.0                     False                     False
# 4       350.0                     False                     False
#
#    Property_Age_10+ Year  Property_Age_5 to 10 Year
# 0                  False                      False  \
# 1                  False                      False
# 2                   True                      False
# 3                  False                       True
# 4                  False                       True
#
#    Property_Age_Under Construction
# 0                            False
# 1                            False
# 2                            False
# 3                            False
# 4                            False

# %% [markdown]
# Aggregate the data to calculate summary statistics or derived metrics such as average sale prices by neighborhood or property type.

# %%
neighborhood_avg_prices = data.groupby('Area_Type')['Price_Lakh'].mean()

# %%
neighborhood_avg_prices

'''
0='Super Built Up Area' 
1='Built Up Area' 
2='Carpet Area' 
3='Plot Area'
'''
# Out:
# "\n0='Super Built Up Area' \n1='Built Up Area' \n2='Carpet Area' \n3='Plot Area'\n"

# %%
Region_avg_prices = data.groupby('Region')['Price_Lakh'].mean()

# %%
Region_avg_prices
# Out:
# Region
# Adaigaon Navi-Mumbai      26.500000
# Adharwadi Mumbai          63.680000
# Airoli Navi-Mumbai        87.625000
# Ambernath Mumbai          36.857143
# Ambika Nagar Mumbai       42.000000
#                            ...
# Village Navi-Mumbai       99.500000
# Wada Mumbai               55.000000
# Walkeshwar Mumbai       1062.500000
# Wayle Nagar               47.000000
# Yagna Nagar              221.333333
# Name: Price_Lakh, Length: 145, dtype: float64

# %% [markdown]
# Identify and handle outliers or extreme values in the data that may affect the analysis or modeling process

# %%
z_scores = np.abs(stats.zscore(data['Price_Lakh']))
z_scores
# Out:
# 0       0.881426
# 1       0.177607
# 2       0.214908
# 3       0.543052
# 4       0.475377
#           ...
# 2575    0.141819
# 2576    0.233857
# 2577    0.101214
# 2578    0.009176
# 2579    0.214908
# Name: Price_Lakh, Length: 2580, dtype: float64

# %%
data_outliers = data[(z_scores > 3)]

# %%
data_outliers
# Out:
#                             Property_Name
# 39                   Swan Lake Apartment   \
# 203                          Sagar Mahal
# 329                Jolly Maker Apartment
# 605   Hiranandani Gardens Richmond Tower
# 634                  Kalpataru Solitaire
# 635                  Kalpataru Solitaire
# 1064                     Unnamed Property
# 1067                     Unnamed Property
# 1416                     Unnamed Property
# 1675                      Piramal Aranya
# 2065                          White City
#
#                                                Location             Region
# 39             1 101 Khar West Mumbai South West Mumbai       South Mumbai  \
# 203   Opposite Gopi Birla School And Sheetal Baug Wa...  Walkeshwar Mumbai
# 329                    Cuffe Parade South Mumbai Mumbai       South Mumbai
# 605   Hiranandani Gardens Powai Hiranandani Gardens ...     Central Mumbai
# 634                       Juhu Mumbai South West Mumbai        Juhu Mumbai
# 635                       Juhu Mumbai South West Mumbai        Juhu Mumbai
# 1064                      Juhu Mumbai South West Mumbai        Juhu Mumbai
# 1067                      Juhu Mumbai South West Mumbai        Juhu Mumbai
# 1416                      Juhu Mumbai South West Mumbai        Juhu Mumbai
# 1675    Byculla East Byculla East Mumbai Harbour Mumbai     Mumbai Harbour
# 2065                          005 Kandivali East Mumbai   Kandivali Mumbai
#
#       Availability  Area_Type  Area_SqFt  Rate_SqFt  Floor_No  Bedroom
# 39               0          1     2715.0      66298         0        4  \
# 203              0          0     2450.0      67350         9        4
# 329              0          0     2135.0      74941        20        5
# 605              0          3     5000.0      33000         6        5
# 634              0          3     3000.0      46000         6        3
# 635              0          3     2800.0      46428         5        3
# 1064             0          0     4363.0      36672         2        4
# 1067             0          3     4200.0      45238         1        4
# 1416             0          3     5700.0      42105         1        4
# 1675             0          1     2800.0      49107        21        4
# 2065             0          3     1000.0    1650000        21        2
#
#       Bathroom  Price_Lakh  Property_Age_0 to 1 Year
# 39           4      1800.0                     False  \
# 203          5      1650.0                     False
# 329          4      1600.0                     False
# 605          6      1650.0                     False
# 634          5      1380.0                     False
# 635          3      1300.0                     False
# 1064         4      1600.0                     False
# 1067         4      1900.0                     False
# 1416         4      2400.0                     False
# 1675         4      1375.0                      True
# 2065         2     16500.0                      True
#
#       Property_Age_1 to 5 Year  Property_Age_10+ Year
# 39                       False                   True  \
# 203                      False                   True
# 329                      False                   True
# 605                       True                  False
# 634                       True                  False
# 635                       True                  False
# 1064                     False                   True
# 1067                     False                   True
# 1416                     False                   True
# 1675                     False                  False
# 2065                     False                  False
#
#       Property_Age_5 to 10 Year  Property_Age_Under Construction
# 39                        False                            False
# 203                       False                            False
# 329                       False                            False
# 605                       False                            False
# 634                       False                            False
# 635                       False                            False
# 1064                      False                            False
# 1067                      False                            False
# 1416                      False                            False
# 1675                      False                            False
# 2065                      False                            False

# %% [markdown]
# 11 records had outlier values in Price_Lakh column

# %% [markdown]
# To store clean values in the new dataset we will take the values less than the threshold

# %%
cleaned_data = data[(z_scores < 3)]

# %%
cleaned_data.to_csv('Cleaned_Mumbai_RealEstate_Data.csv', index=False)
